# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras import layers, Model, callbacks, optimizers
from tensorflow.keras import utils
import matplotlib.pyplot as plt
import ipywidgets as widgets
# Out:
# 2026-06-10 01:08:16.657880: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-10 01:08:16.679395: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# read data
df_data = pd.read_parquet('../../Data/training_data.parquet.gzip')
print(df_data.shape)
len(df_data.index.get_level_values(0).unique())
# Out:
# (1825488, 8)
# 336

# %%
# calculate daily changes by ticker
df_analysis = df_data.groupby(level='ticker', as_index=False).apply(pd.DataFrame.pct_change)

# calculate the standard deviation of close price daily change by ticker
df_analysis = df_analysis.groupby(level='ticker', as_index=True)['Close'].apply(np.std)

# sort valeus
df_analysis.sort_values(inplace=True)

# pick tickers: 2*most_volatile, 2*most_stable, 2*in_middle
mid = int(len(df_analysis.index)/2)
tickers_ft = df_analysis.index[:5].append(df_analysis.index[mid:mid+5]).append(df_analysis.index[-5:])
tickers_ft = tickers_ft.tolist()[:10]
tickers_ft
# Out:
# ['CET', 'AJG', 'FNWD', 'CFFN', 'RY', 'FDBC', 'VABK', 'FCF', 'PFC', 'BUSE']

# %%
# common variables

seq_length = 7   # use the last 7 days to predict the next day
features = ["Open", "High", "Low", "Close"]
seq_length = 7
idx = pd.IndexSlice

# %%
def get_ticker_df(ticker, features=features):
    return df_data.loc[idx[ticker, :], features]

def create_sequence_dataset(df, seq_length=seq_length, batch_size=None, shuffle=False, seed=88):
    return utils.timeseries_dataset_from_array(
        data=df.to_numpy(dtype=np.float32),
        targets=df["Close"].iloc[seq_length:].to_numpy(dtype=np.float32),
        sequence_length=seq_length,
        batch_size=batch_size,
        shuffle=shuffle,
        seed=seed,
    )

def dataset_to_numpy(dataset):
    x_list, y_list = [], []
    for x, y in dataset:
        x_list.append(x.numpy())
        y_list.append(y.numpy())
    return np.stack(x_list), np.asarray(y_list)

# %% [markdown]
# ## Similarity, Graph, Evaluate by dataset

# %%
import sys
import os
sys.path.insert(0, '.')
from CKA import linear_CKA

model_layers = [3, 5, 7, 9]
model_states = ['NoTraining', 'optimal']

os.makedirs('outputs_CKA', exist_ok=True)

evaluation_mape = []

for num_layers in model_layers:
    for state in model_states:
        MODEL_PATH = f'saved_models/{num_layers}_Layers_{state}.keras'
        model = tf.keras.models.load_model(MODEL_PATH)
        model.compile(loss="mean_absolute_percentage_error")

        # Build a model returning all representations except the final Dense output:
        # all_reprs[0] = model input, all_reprs[k] = k-th hidden LSTM output
        all_layer_outputs = [model.layers[i].output for i in range(len(model.layers) - 1)]
        repr_model = tf.keras.Model(inputs=model.input, outputs=all_layer_outputs)

        for ticker in tickers_ft:
            df_ticker = get_ticker_df(ticker)
            dataset = create_sequence_dataset(df_ticker, batch_size=None, shuffle=False)
            x_all, y_all = dataset_to_numpy(dataset)

            # all_reprs[j]: shape (n_samples, seq_len, d_j)
            all_reprs = repr_model.predict(x_all, verbose=0)

            n_samples = x_all.shape[0]
            n_hidden = len(model.layers) - 2  # exclude InputLayer and Dense

            # Per-sample intra-layer CKA: for each sample, compute CKA(layer_input, layer_output)
            # treating the seq_len timesteps as the sample dimension within each data sample
            cka_matrix = np.zeros((n_samples, n_hidden))
            for sample_idx in range(n_samples):
                for layer_idx in range(n_hidden):
                    x_in  = all_reprs[layer_idx][sample_idx]      # (seq_len, d_in)
                    x_out = all_reprs[layer_idx + 1][sample_idx]  # (seq_len, d_out)
                    cka_matrix[sample_idx, layer_idx] = linear_CKA(x_in, x_out)

            # Save CKA results as CSV
            df_cka = pd.DataFrame(
                cka_matrix,
                columns=[f"Layer_{i + 1}" for i in range(n_hidden)]
            )
            df_cka.index.name = "sample_idx"
            df_cka.to_csv(f'outputs_CKA/{num_layers}Layers_{state}_{ticker}_cka.csv')

            # Visualization: one line per samplecolumns=ticker_order, one graph per (num_layers, state, ticker)
            fig, ax = plt.subplots(figsize=(10, 6))
            layer_indices = list(range(1, n_hidden + 1))
            alpha = max(0.05, min(0.3, 30.0 / n_samples))
            for sample_idx in range(n_samples):
                ax.plot(layer_indices, cka_matrix[sample_idx],
                        alpha=alpha, linewidth=0.6, color='steelblue')
            ax.set_xlabel('Hidden Layer Index')
            ax.set_ylabel('CKA Similarity Score')
            ax.set_title(f'Intra-layer CKA  |  {num_layers} Layers  |  {state}  |  {ticker}')
            ax.set_xticks(layer_indices)
            ax.set_xticklabels([f'Layer {i}' for i in layer_indices])
            plt.tight_layout()
            plt.savefig(f'outputs_CKA/{num_layers}Layers_{state}_{ticker}_cka.png', dpi=150)
            plt.close()

            # Evaluation
            mape = float(model.evaluate(x_all, y_all, verbose=0))
            evaluation_mape.append({
                "num_layers": num_layers,
                "model_state": state,
                "ticker": ticker,
                "mape": mape
            })

# Save evaluation
df_evaluation = pd.DataFrame(evaluation_mape)
ticker_order = df_evaluation["ticker"].drop_duplicates().tolist()

df_eval = (
    df_evaluation.pivot_table(
        index=["num_layers", "model_state"],
        columns="ticker",
        values="mape",
    )
    .reindex(columns=ticker_order)
    .reset_index()
)
df_eval.columns.name = None
df_eval.to_csv('evaluation/evaluation_mape_by_dataset.csv', index=False)
# Out:
# 2026-06-09 23:55:06.017393: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-09 23:55:06.079144: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-09 23:55:06.080855: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-09 23:55:06.082925: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-09 23:55:06.085370: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-09 23:55:06.086353: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-09 23:55:06.182257: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-09 23:55:06.183121: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-09 23:55:06.183938: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-09 23:55:06.184858: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21316 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# /home/mchen/miniconda3/envs/PraxisDoc/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 24 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 2026-06-09 23:55:07.309785: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781063707.470868   61266 service.cc:145] XLA service 0x7bf3cc0044d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781063707.470952   61266 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2026-06-09 23:55:07.502937: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-06-09 23:55:07.586443: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# I0000 00:00:1781063707.789857   61266 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-06-09 23:55:12.814808: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:55:16.809068: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:55:21.166290: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:55:24.922989: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:55:28.693174: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:55:32.852840: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:55:37.143886: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:55:40.523429: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:55:44.618631: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:55:48.554610: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:55:53.309807: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:55:57.474823: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:56:01.449349: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:56:05.616704: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:56:09.772331: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:56:13.734890: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:56:17.727156: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:56:21.760016: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:56:26.496556: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/miniconda3/envs/PraxisDoc/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 36 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 2026-06-09 23:56:30.617308: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:56:36.543502: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:56:41.098960: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:56:46.537375: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:56:50.497363: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:56:55.185724: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:56:59.621978: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:57:03.988855: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:57:07.794627: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:57:13.040350: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:57:17.659121: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:57:23.294261: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:57:27.422827: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:57:31.784027: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:57:36.581709: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:57:40.692616: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:57:45.201411: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:57:51.251495: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:57:56.153950: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:58:00.874459: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/miniconda3/envs/PraxisDoc/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 48 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 2026-06-09 23:58:05.466812: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:58:11.779889: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:58:16.765954: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:58:21.411858: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:58:25.752620: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:58:31.103935: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:58:37.423190: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:58:42.084681: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:58:46.383113: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:58:50.762994: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:58:55.767242: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:59:02.763512: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:59:07.973808: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:59:13.060504: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:59:18.206923: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:59:23.549866: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:59:28.805446: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-09 23:59:36.302704: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:59:41.586222: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-09 23:59:46.786949: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/miniconda3/envs/PraxisDoc/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 60 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 2026-06-09 23:59:52.164451: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:00:00.297400: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:00:06.308821: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-10 00:00:12.305773: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:00:17.794888: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:00:24.063179: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-10 00:00:30.096989: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-10 00:00:35.954734: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:00:41.171773: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:00:46.779078: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:00:53.013815: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:01:04.196563: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:01:10.452653: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-10 00:01:16.680084: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:01:23.419578: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:01:29.198389: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-10 00:01:35.518581: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-10 00:01:41.972761: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:01:48.768496: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 00:01:55.377429: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Evaulate with all dataset

# %%
import sys
import os
sys.path.insert(0, '.')

model_layers = [3, 5, 7, 9]
model_states = ['NoTraining', 'optimal']

os.makedirs('outputs_CKA', exist_ok=True)

evaluation_mape = []
df_ticker = pd.DataFrame()
for ticker in tickers_ft:
    if df_ticker.empty:
        df_ticker = get_ticker_df(ticker)
    else:
        df_ticker = pd.concat([df_ticker, get_ticker_df(ticker)], axis=0)


for num_layers in model_layers:
    for state in model_states:
        MODEL_PATH = f'saved_models/{num_layers}_Layers_{state}.keras'
        model = tf.keras.models.load_model(MODEL_PATH)
        model.compile(loss="mean_absolute_percentage_error")

        # Build a model returning all representations except the final Dense output:
        # all_reprs[0] = model input, all_reprs[k] = k-th hidden LSTM output
        all_layer_outputs = [model.layers[i].output for i in range(len(model.layers) - 1)]
        repr_model = tf.keras.Model(inputs=model.input, outputs=all_layer_outputs)

        dataset = create_sequence_dataset(df_ticker, batch_size=None, shuffle=False)
        x_all, y_all = dataset_to_numpy(dataset)

        # Evaluation
        mape = float(model.evaluate(x_all, y_all, verbose=0))
        evaluation_mape.append({
            "num_layers": num_layers,
            "model_state": state,
            "mape": mape
        })
        
df_evaluation = pd.DataFrame(evaluation_mape)
df_eval = (
    df_evaluation.pivot_table(
        index="model_state",
        columns="num_layers",
        values="mape"
    )
    .reindex()
    .reset_index()
)
df_eval.columns.name = None
df_eval.to_csv('evaluation/evaluation_mape_all.csv', index=False)
# Out:
# /home/mchen/miniconda3/envs/PraxisDoc/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 24 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 2026-06-10 01:10:31.595854: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 01:10:36.378846: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/miniconda3/envs/PraxisDoc/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 36 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 2026-06-10 01:10:41.158008: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 01:10:46.430770: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/miniconda3/envs/PraxisDoc/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 48 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 2026-06-10 01:10:51.595854: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 01:10:57.763109: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/miniconda3/envs/PraxisDoc/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 60 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 2026-06-10 01:11:03.965893: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-10 01:11:11.375455: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
