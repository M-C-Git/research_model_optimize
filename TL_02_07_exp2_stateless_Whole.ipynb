# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras import layers, Model, callbacks, optimizers
from tensorflow.keras import utils
import matplotlib.pyplot as plt
import ipywidgets as widgets

# %%
# read data
df_data = pd.read_parquet('../../Data/training_data.parquet.gzip')
print(df_data.shape)
len(df_data.index.get_level_values(0).unique())
# Out:
# (1825488, 8)
# 336

# %%
# calculate daily changes by ticker
df_analysis = df_data.groupby(level='ticker', as_index=False).apply(pd.DataFrame.pct_change)

# calculate the standard deviation of close price daily change by ticker
df_analysis = df_analysis.groupby(level='ticker', as_index=True)['Close'].apply(np.std)

# sort valeus
df_analysis.sort_values(inplace=True)

# pick tickers: 2*most_volatile, 2*most_stable, 2*in_middle
mid = int(len(df_analysis.index)/2)
tickers_ft = df_analysis.index[:5].append(df_analysis.index[mid:mid+5]).append(df_analysis.index[-5:])
tickers_ft = tickers_ft.tolist()[:10]
tickers_ft
# Out:
# ['CET', 'AJG', 'FNWD', 'CFFN', 'RY', 'FDBC', 'VABK', 'FCF', 'PFC', 'BUSE']

# %%
# common variables

seq_length = 7   # use the last 7 days to predict the next day
features = ["Open", "High", "Low", "Close"]
seq_length = 7
idx = pd.IndexSlice

# %%
def get_ticker_df(ticker, features=features):
    return df_data.loc[idx[ticker, :], features]

def create_sequence_dataset(df, seq_length=seq_length, batch_size=None, shuffle=False, seed=88):
    return utils.timeseries_dataset_from_array(
        data=df.to_numpy(dtype=np.float32),
        targets=df["Close"].iloc[seq_length:].to_numpy(dtype=np.float32),
        sequence_length=seq_length,
        batch_size=batch_size,
        shuffle=shuffle,
        seed=seed,
    )

def dataset_to_numpy(dataset):
    x_list, y_list = [], []
    for x, y in dataset:
        x_list.append(x.numpy())
        y_list.append(y.numpy())
    return np.stack(x_list), np.asarray(y_list)

# %% [markdown]
# ## Similarity, Graph, Evaluate by dataset

# %%
import sys
import os
sys.path.insert(0, '.')
from CKA import linear_CKA

model_layers = [3, 5, 7, 9]
model_states = ['optimal']

os.makedirs('outputs_CKA', exist_ok=True)

evaluation_mape = []

for num_layers in model_layers:
    for state in model_states:
        MODEL_PATH = f'saved_models/{num_layers}_Layers_{state}.keras'
        model = tf.keras.models.load_model(MODEL_PATH)
        model.compile(loss="mean_absolute_percentage_error")

        # Build a model returning all representations except the final Dense output:
        # all_reprs[0] = model input, all_reprs[k] = k-th hidden LSTM output
        all_layer_outputs = [model.layers[i].output for i in range(len(model.layers) - 1)]
        repr_model = tf.keras.Model(inputs=model.input, outputs=all_layer_outputs)

        for ticker in tickers_ft:
            df_ticker = get_ticker_df(ticker)
            dataset = create_sequence_dataset(df_ticker, batch_size=None, shuffle=False)
            x_all, y_all = dataset_to_numpy(dataset)

            # all_reprs[j]: shape (n_samples, seq_len, d_j)
            all_reprs = repr_model.predict(x_all, verbose=0)

            n_samples = x_all.shape[0]
            n_hidden = len(model.layers) - 2  # exclude InputLayer and Dense

            # Per-sample intra-layer CKA: for each sample, compute CKA(layer_input, layer_output)
            # treating the seq_len timesteps as the sample dimension within each data sample
            cka_matrix = np.zeros((n_samples, 1))
            for sample_idx in range(n_samples):
                for layer_idx in range(n_hidden):
                    x_in  = all_reprs[0][sample_idx]         # (seq_len, d_in)
                    x_out = all_reprs[n_hidden][sample_idx]  # (seq_len, d_out)
                    cka_matrix[sample_idx, 0] = linear_CKA(x_in, x_out)

            # Save CKA results as CSV
            df_cka = pd.DataFrame(cka_matrix, columns=["CKA"])
            df_cka.index.name = "sample_idx"
            df_cka.to_csv(f'outputs_CKA/whole_CKA/{num_layers}Layers_{state}_{ticker}_cka.csv')
# Out:
# 2026-06-13 17:23:06.852081: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-13 17:23:06.938439: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-13 17:23:06.940309: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-13 17:23:06.945707: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-13 17:23:06.947135: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-13 17:23:06.948167: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-13 17:23:07.039190: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-13 17:23:07.040166: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-13 17:23:07.041017: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-06-13 17:23:07.043041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21628 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2026-06-13 17:23:08.259425: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781385788.394049   17200 service.cc:145] XLA service 0x770648004990 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1781385788.394075   17200 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2026-06-13 17:23:08.432067: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-06-13 17:23:08.512098: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# I0000 00:00:1781385788.703204   17200 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-06-13 17:23:10.324854: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:11.474742: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:23:12.653817: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:13.972429: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:15.051107: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:23:16.227902: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:23:17.428342: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:18.648995: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:19.903529: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:21.280453: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:23.627409: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:25.185659: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:23:26.775546: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:28.466120: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:30.004950: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:23:31.617033: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:23:33.242282: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:34.911421: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:36.553376: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:38.388739: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:41.722225: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:43.942725: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:23:46.167404: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:48.372246: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:50.470198: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:23:52.719643: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:23:54.835030: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:57.085807: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:23:59.345611: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:24:01.917222: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:24:05.732891: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:24:08.211132: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:24:10.804055: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:24:13.431749: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:24:15.861851: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:24:18.374067: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/mchen/PraxisDoc/Experiments/FIN_experiment_cka/./CKA.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   return hsic / (var1 * var2)
# 2026-06-13 17:24:20.833143: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:24:23.308604: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-06-13 17:24:25.733881: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
